# %%
import pandas as pd

# %%
pd.to_datetime('2018-01-15 3:45pm')
# Out:
# Timestamp('2018-01-15 15:45:00')

# %%
pd.to_datetime('2018-01-15 15:45:00')
# Out:
# Timestamp('2018-01-15 15:45:00')

# %%
pd.to_datetime("7/8/1952",dayfirst=True)
# Out:
# Timestamp('1952-08-07 00:00:00')

# %%
pd.to_datetime(['2018-01-05','7/8/1952','oct 10 1995'])
# Out:
# DatetimeIndex(['2018-01-05', '1952-07-08', '1995-10-10'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2/25/10','8/6/17','12/15/12'],format='%m/%d/%y')
# Out:
# DatetimeIndex(['2010-02-25', '2017-08-06', '2012-12-15'], dtype='datetime64[ns]', freq=None)

# %%
ds=pd.read_csv("Electricity data.csv")

# %%
ds.shape
# Out:
# (4383, 5)

# %%
ds.head(3)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN

# %%
ds.tail(3)
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
ds.dtypes
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object

# %%
ds=ds.set_index("Date") # make the date column a dataframe's index
ds.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN

# %%
ds=pd.read_csv("Electricity data.csv",index_col=0,parse_dates=True)

# %%
ds.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN

# %%
# add columns with year,mouth and weekday name.
ds["Year"]=ds.index.year
ds["Month"]=ds.index.month
ds["Weekday Name"]=ds.index.day_name()
ds.sample(5,random_state=0) # display a random sampling of 5 rows.
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008      8     Saturday
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8     Thursday
# 2009-08-27     1281.057     NaN      NaN         NaN  2009      8     Thursday
# 2015-10-02     1391.050  81.229  160.641     241.870  2015     10       Friday
# 2009-06-02     1201.522     NaN      NaN         NaN  2009      6      Tuesday

# %%
#Select data for a single day using a string such as '2017-08-10‘
ds.loc['2017-08-10']
# Out:
# Consumption     1351.491
# Wind             100.274
# Solar              71.16
# Wind+Solar       171.434
# Year                2017
# Month                  8
# Weekday Name    Thursday
# Name: 2017-08-10 00:00:00, dtype: object

# %%
#Select a slice of days, such as '2014-01-20':'2014-01-22' 

ds.loc['2014-01-20':'2014-01-22']
# Out:
#             Consumption    Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2014-01-20     1590.687  78.647   6.371      85.018  2014      1       Monday
# 2014-01-21     1624.806  15.643   5.835      21.478  2014      1      Tuesday
# 2014-01-22     1625.155  60.259  11.992      72.251  2014      1    Wednesday

# %%
#Select the entire year 2006 
ds.loc["2006"]
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006      1       Sunday
# 2006-01-02     1380.521   NaN    NaN         NaN  2006      1       Monday
# 2006-01-03     1442.533   NaN    NaN         NaN  2006      1      Tuesday
# 2006-01-04     1457.217   NaN    NaN         NaN  2006      1    Wednesday
# 2006-01-05     1477.131   NaN    NaN         NaN  2006      1     Thursday
# ...                 ...   ...    ...         ...   ...    ...          ...
# 2006-12-27     1284.676   NaN    NaN         NaN  2006     12    Wednesday
# 2006-12-28     1314.603   NaN    NaN         NaN  2006     12     Thursday
# 2006-12-29     1274.646   NaN    NaN         NaN  2006     12       Friday
# 2006-12-30     1237.751   NaN    NaN         NaN  2006     12     Saturday
# 2006-12-31     1144.398   NaN    NaN         NaN  2006     12       Sunday
#
# [365 rows x 7 columns]

# %%
#Select the second month of 2012
ds.loc['2012-02']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2012-02-01     1511.866  199.607  43.502     243.109  2012      2    Wednesday
# 2012-02-02     1563.407   73.469  44.675     118.144  2012      2     Thursday
# 2012-02-03     1563.631   36.352  46.510      82.862  2012      2       Friday
# 2012-02-04     1372.614   20.551  45.225      65.776  2012      2     Saturday
# 2012-02-05     1279.432   55.522  54.572     110.094  2012      2       Sunday
# 2012-02-06     1574.766   34.896  55.389      90.285  2012      2       Monday
# 2012-02-07     1615.078  100.312  19.867     120.179  2012      2      Tuesday
# 2012-02-08     1613.774   93.763  36.930     130.693  2012      2    Wednesday
# 2012-02-09     1591.532  132.219  19.042     151.261  2012      2     Thursday
# 2012-02-10     1581.287   52.122  34.873      86.995  2012      2       Friday
# 2012-02-11     1377.404   32.375  44.629      77.004  2012      2     Saturday
# ...

# %%
#Visualizing Time Series Data
ds['Consumption'].plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cols_plot=['Consumption', 'Solar', 'Wind']
axes=ds[cols_plot].plot(linewidth=0.5,marker='+',alpha=0.5, linestyle='None', figsize=(11, 9), 
subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

# %%
ax = ds.loc['2017', 'Consumption'].plot() # plot for single year
ax.set_ylabel('Daily Consumption (GWh)')
# Out:
# Text(0, 0.5, 'Daily Consumption (GWh)')

# %%
ax = ds.loc['2017-01':'2017-02', 'Consumption'].plot(marker='o', linestyle='-') # ploting for  a month
ax.set_ylabel('Daily Consumption (GWh)')
# Out:
# Text(0, 0.5, 'Daily Consumption (GWh)')

# %% [markdown]
# # Example: Introducing vertical gridlines on a weekly time scale (instead of on the first day of each month)

# %%
import matplotlib.dates as mdates
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
ax.plot(ds.loc['2017-01':'2017-02','Consumption'], marker='o', linestyle='-')
ax.set_ylabel('Daily Consumption (GWh)')
ax.set_title('Jan-Feb 2017 Electricity Consumption')
# Set x-axis major ticks to weekly interval, on Mondays
ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))
# Format x-tick labels as 3-letter month name and day number
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'));

# %% [markdown]
# # Seasonality
# Explore the seasonality of our data with box plots, using seaborn’s boxplot() function to group the data by different time periods and display the distributions for each group

# %%
ds
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1       Sunday
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1       Monday
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1      Tuesday
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1    Wednesday
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1     Thursday
# ...                 ...      ...     ...         ...   ...    ...          ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12    Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12     Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12       Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12     Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12       Sunday
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(3, 1, figsize=(11, 10), sharex=True)
for name, ax in zip(['Consumption', 'Solar', 'Wind'], axes):
 sns.boxplot(data=ds, x='Month', y=name, ax=ax)
 ax.set_ylabel('GWh')
 ax.set_title(name)
# Remove the automatic 
#x-axis label from all but the bottom subplot
 if ax != axes[-1]:
    ax.set_xlabel("")

# %%
sns.boxplot(data=ds, x='Weekday Name', y='Consumption') # weekly consumption
# Out:
# <AxesSubplot:xlabel='Weekday Name', ylabel='Consumption'>

# %% [markdown]
# # Example :
# Create a sequence of uniformly spaced dates from 1998-03-10 through 1998-03-15 at daily frequency

# %%
pd.date_range('1998-03-10', '1998-03-15', freq='D')
# Out:
# DatetimeIndex(['1998-03-10', '1998-03-11', '1998-03-12', '1998-03-13',
#                '1998-03-14', '1998-03-15'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Example
#  To select an arbitrary sequence of date/time values from a pandas time series,# we need to use a DatetimeIndex, rather than simply a list of date/time strings

# %%
times_sample = pd.to_datetime(['2013-02-03', '2013-02-06', '2013-02-08'])
# Select the specified dates and just the Consumption column
consum_sample = ds.loc[times_sample, ['Consumption']]
consum_sample
# Out:
#             Consumption
# Date
# 2013-02-03     1109.639
# 2013-02-06     1451.449
# 2013-02-08     1433.098

# %%
# Convert the data to daily frequency, without filling any missings
consum_freq = consum_sample.asfreq('D')
# Create a column with missings forward filled
consum_freq['Consumption - Forward Fill'] = consum_sample.asfreq('D', method='ffill')
consum_freq
# Out:
#             Consumption  Consumption - Forward Fill
# Date
# 2013-02-03     1109.639                    1109.639
# 2013-02-04          NaN                    1109.639
# 2013-02-05          NaN                    1109.639
# 2013-02-06     1451.449                    1451.449
# 2013-02-07          NaN                    1451.449
# 2013-02-08     1433.098                    1433.098

# %% [markdown]
# # Example
# #Specify the data columns we want to include (i.e. exclude Year, Month, Weekday Name)

# %%
data_columns = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']
# Resample to weekly frequency, aggregating with mean
opsd_weekly_mean = ds[data_columns].resample('W').mean()
opsd_weekly_mean.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01  1069.184000   NaN    NaN         NaN
# 2006-01-08  1381.300143   NaN    NaN         NaN
# 2006-01-15  1486.730286   NaN    NaN         NaN

# %% [markdown]
# # Example :
#     Plot daily and weekly Solar time series together over a single six-month period to compare them

# %%
from matplotlib import pyplot as plt
# Start and end of the date range to extract
start, end = '2017-01', '2017-06'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots()
ax.plot(ds.loc[start:end, 'Solar'],
marker='.', linestyle='-', linewidth=0.5, label='Daily')
ax.plot(opsd_weekly_mean.loc[start:end, 'Solar'],
marker='o', markersize=8, linestyle='-', label='Weekly Mean Resample')
ax.set_ylabel('Solar Production (GWh)')
ax.legend();

# %% [markdown]
# # Example :
# Plot daily and weekly Solar time series together over a single six-month period to compare them

# %%
start,end="2017-01","2017-06"
fig,ax=plt.subplots()
ax.plot(ds.loc[start:end,'Solar'],marker='.',linestyle='-',linewidth=0.5,label='Daily')
ax.plot(opsd_weekly_mean.loc[start:end, 'Solar'],
marker='o', markersize=8, linestyle='-', label='Weekly Mean Resample')
ax.set_ylabel('Solar Production (GWh)')
ax.legend();

# %%
#Example : Resample the data to monthly frequency, aggregating with sum totals instead of the mean
monthly_data=ds[data_columns].resample('M').sum()
monthly_data.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-31    45304.704   0.0    0.0         0.0
# 2006-02-28    41078.993   0.0    0.0         0.0
# 2006-03-31    43978.124   0.0    0.0         0.0

# %%
#Example :
 #Plot electricity consumption as a line plot, and the wind and solar power production together as a stacked area plot
ax.plot(ds['Consumption'],marker='*',markersize=8,linewidth=1,label='consumption',color='black')
ds[['Wind', 'Solar']].plot.area(ax=ax, linewidth=0)

ax.xaxis.set_major_locator(mdates.YearLocator())
ax.legend()
ax.set_ylabel('Monthly Total (GWh)')
# Out:
# Text(17.200000000000003, 0.5, 'Monthly Total (GWh)')

# %% [markdown]
# # Example :
# Computing the ratio of Wind+Solar to Consumption for each year

# %%
opsd_annual = ds[data_columns].resample('A').sum(min_count=360)
# The default index of the resampled DataFrame is the last day of each year, ('2006-12-31', '2007-12-31', etc.) so to make life easier, set the index  to the year component
opsd_annual = opsd_annual.set_index(opsd_annual.index.year)
opsd_annual.index.name = 'Year'
# Compute the ratio of Wind+Solar to Consumption
opsd_annual['Wind+Solar/Consumption'] = opsd_annual['Wind+Solar'] / opsd_annual['Consumption']
# Plot from 2012 onwards, because there is no solar production data in earlier years
ax = opsd_annual.loc[2012:, 'Wind+Solar/Consumption'].plot.bar(color='C0')
ax.set_ylabel('Fraction')
ax.set_ylim(0, 0.3)
ax.set_title('Wind + Solar Share of Annual Electricity Consumption')
plt.xticks(rotation=0);

# %% [markdown]
# # Rolling Window

# %%
# Compute the centered 7-day rolling mean
opsd_7d = ds[data_columns].rolling(7, center=True).mean()
opsd_7d.head(10)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01          NaN   NaN    NaN         NaN
# 2006-01-02          NaN   NaN    NaN         NaN
# 2006-01-03          NaN   NaN    NaN         NaN
# 2006-01-04  1361.471429   NaN    NaN         NaN
# 2006-01-05  1381.300143   NaN    NaN         NaN
# 2006-01-06  1402.557571   NaN    NaN         NaN
# 2006-01-07  1421.754429   NaN    NaN         NaN
# 2006-01-08  1438.891429   NaN    NaN         NaN
# 2006-01-09  1449.769857   NaN    NaN         NaN
# 2006-01-10  1469.994857   NaN    NaN         NaN

# %%
data_columns
# Out:
# ['Consumption', 'Wind', 'Solar', 'Wind+Solar']

# %% [markdown]
# # Example :
# Comparison between Rolling mean and Resampling

# %%
# Start and end of the date range to extract
start, end = '2017-01', '2017-06'
# Plot daily, weekly resampled, and 7-day rolling mean time series together
fig, ax = plt.subplots()
ax.plot(ds.loc[start:end, 'Solar'],
marker='.', linestyle='-', linewidth=0.5, label='Daily')
ax.plot(opsd_weekly_mean.loc[start:end, 'Solar'],
marker='o', markersize=8, linestyle='-', 
label='Weekly Mean Resample')
ax.plot(opsd_7d.loc[start:end, 'Solar'],
marker='.', linestyle='-', label='7-d Rolling Mean')
ax.set_ylabel('Solar Production (GWh)')
ax.legend();

# %% [markdown]
# # Trends
# Example : Plot the 7-day and 365-day rolling mean electricity consumption, along with the daily time series

# %%
# The min_periods=360 argument accounts for a few isolated missing days in the# wind and solar production time series
opsd_365d = ds[data_columns].rolling(window=365, center=True, min_periods=360).mean()
# Plot daily, 7-day rolling mean, and 365-day rolling mean time series
fig, ax = plt.subplots()
ax.plot(ds['Consumption'], marker='.', markersize=2, color='0.6',linestyle='None', label='Daily')
ax.plot(opsd_7d['Consumption'], linewidth=2, label='7-d Rolling Mean')
ax.plot(opsd_365d['Consumption'], color='0.2', linewidth=3,label='Trend (365-d Rolling Mean)')
# Set x-ticks to yearly interval and add legend and labels
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Consumption (GWh)')
ax.set_title('Trends in Electricity Consumption');

# %% [markdown]
# # Example :
# Trends in wind and solar production

# %%
# Plot 365-day rolling mean time series of wind and solar power
fig, ax = plt.subplots()
for nm in ['Wind', 'Solar', 'Wind+Solar']:
    ax.plot(opsd_365d[nm], label=nm)
    # Set x-ticks to yearly interval, adjust y-axis limits, add legend and labels
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.set_ylim(0, 400)
    ax.legend()
    ax.set_ylabel('Production (GWh)')
    ax.set_title('Trends in Electricity Production (365-d Rolling Means)');
